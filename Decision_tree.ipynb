# %% [markdown]
# <a href="https://colab.research.google.com/github/J4m331/COMP3608-IS-Project/blob/Create-Decision-Tree-Folder/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 95.8 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed scikit-learn-1.8.0

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
def importdata():
  url1 = "https://raw.githubusercontent.com/J4m331/COMP3608-IS-Project/refs/heads/Create-Decision-Tree-Folder/data/vgData2024.csv"
  balance_data1 = pd.read_csv(url1, header=0)
  print("vgData2024 Length:", len(balance_data1))
  print("vgData2024 Shape: ", balance_data1.shape)
  print("vgData2024 Head:\n", balance_data1.head())
  return balance_data1

importdata()
# Out:
# vgData2024 Length: 16219
# vgData2024 Shape:  (16219, 9)
# vgData2024 Head:
#                                        Name           Publisher Platform  \
# 0                              '98 Koshien     Magical Company       PS
# 1               .hack//G.U. Vol.1//Rebirth  Namco Bandai Games      PS2
# 2             .hack//G.U. Vol.2//Reminisce  Namco Bandai Games      PS2
# 3  .hack//G.U. Vol.2//Reminisce (jp sales)  Namco Bandai Games      PS2
# 4            .hack//G.U. Vol.3//Redemption  Namco Bandai Games      PS2
#
#           Genre Release_Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0        Sports   1998-06-18      0.15      0.10      0.12         0.03
# 1  Role-Playing       2006.0      0.00      0.00      0.17         0.00
# 2  Role-Playing       2006.0      0.11      0.09      0.00         0.03
# 3  Role-Playing       2006.0      0.00      0.00      0.16         0.00
# 4  Role-Playing       2007.0      0.00      0.00      0.17         0.00
#                                           Name           Publisher Platform  \
# 0                                  '98 Koshien     Magical Company       PS
# 1                   .hack//G.U. Vol.1//Rebirth  Namco Bandai Games      PS2
# 2                 .hack//G.U. Vol.2//Reminisce  Namco Bandai Games      PS2
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)  Namco Bandai Games      PS2
# 4                .hack//G.U. Vol.3//Redemption  Namco Bandai Games      PS2
# ...                                        ...                 ...      ...
# 16214               thinkSMART: Chess for Kids  Mentor Interactive       DS
# 16215                             uDraw Studio                 THQ      Wii
# 16216             uDraw Studio: Instant Artist                 THQ      Wii
# 16217             uDraw Studio: Instant Artist                 THQ     X360
# 16218             ¡Shin Chan Flipa en colores!           505 Games       DS
#
#               Genre Release_Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0            Sports   1998-06-18      0.15      0.10      0.12         0.03
# 1      Role-Playing       2006.0      0.00      0.00      0.17         0.00
# 2      Role-Playing       2006.0      0.11      0.09      0.00         0.03
# 3      Role-Playing       2006.0      0.00      0.00      0.16         0.00
# 4      Role-Playing       2007.0      0.00      0.00      0.17         0.00
# ...             ...          ...       ...       ...       ...          ...
# 16214          Misc       2011.0      0.01      0.00      0.00         0.00
# 16215          Misc       2010.0      1.65      0.57      0.00         0.20
# 16216          Misc       2011.0      0.06      0.09      0.00         0.02
# 16217          Misc       2011.0      0.01      0.01      0.00         0.00
# 16218      Platform       2007.0      0.00      0.00      0.14         0.00
#
# [16219 rows x 9 columns]

# %%
def splitdataset(balance_data):
  X = balance_data.values[:, 1:5].values
  Y = balance_data.values[:, 0].values
