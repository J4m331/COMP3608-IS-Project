# %% [markdown]
# Genetic Algorithm

# %% [markdown]
# Helper Functions

# %%
import numpy as np
import pandas as pd

def top_k(arr, k):
    return np.argpartition(arr, -k)[-k:]

def elitism(e, population, fitnesses):
    top = top_k(fitnesses, e)
    return population[top]

class Selector(object):
    def __init__(self):
        super().__init__()

    def prep_selector(self, fitnesses):
        pass

    def select(self, population):
        pass


class RouletteWheelSelector(Selector):
    def __init__(self):
        super().__init__()
        self.table = []

    def prep_selector(self, fitnesses):
        transformed = np.exp(fitnesses)
        total = np.sum(transformed)
        self.table = transformed / total
        self.indicies = np.arange(0, len(fitnesses), 1, dtype=int)

    def select(self, population):
        parent1_idx, parent2_idx = np.random.choice(self.indicies, size=2, replace=False, p=self.table)
        parent1 = population[parent1_idx, :]
        parent2 = population[parent2_idx, :]
        return parent1, parent2

class TournamentSelection(Selector):
    def __init__(self):
        super().__init__()
        self.table = []

    def prep_selector(self, fitnesses):
        self.table = fitnesses

    def select(self,population):
        indicies = np.arange(0, len(population), 1, dtype=int)
        sub_population = population[indicies]
        sub_pop_fitnesses = self.table[indicies]
        parent1_idx, parent2_idx = top_k(sub_pop_fitnesses, 2)
        return sub_population[parent1_idx], sub_population[parent2_idx]


def single_point(parent1, parent2):
    point = np.random.randint(1, len(parent1))
    child = np.zeros_like(parent1)
    child[:point] = parent1[:point]
    child[point:] = parent2[point:]
    return child


def interpolation(parent1, parent2):
    lambda_point = np.random.uniform()
    return lambda_point * parent1 +  (1 - lambda_point) * parent2

def uniform(parent1, parent2):
    selection = np.random.randint(0, 2, size=len(parent1))
    neg_selection = 1 - selection
    child = parent1 * selection + parent2 * neg_selection
    return child

class Company:
    def __init__(self, name):
        self.name = name
        self.sales2026 = 0;
        self.sales2024 = 0;
        self.profit = 0

# %% [markdown]
# Random Data Sampling for testing

# %%
df_2024 = pd.read_csv("../data/vgData2024.csv")
df_2026 = pd.read_csv("../data/vgData2024.csv")

df_2024_RS=df_2024.sample(n=1000, random_state=250)
df_2026_RS=df_2026.sample(n=1000, random_state=250)

companies = []

#With both datasets having the same entires, the same seed would return the exact same entires in both datasets
# Out:
#                                                     Name  \
# 6646                                  Kenka Bancho Otome
# 13689  The Chronicles of Narnia: The Lion, The Witch ...
# 10628                                          Purr Pals
# 8004                                 Mega Man Powered Up
# 18                          007: The World is not Enough
# ...                                                  ...
# 10647                                   Puyo Puyo Sun 64
# 11288                         RollerCoaster Tycoon World
# 13754            The Fairly Odd Parents: Enter the Cleft
# 4501                                        Finding Nemo
# 13439   Tatsunoko vs. Capcom: Cross Generation of Heroes
#
#                         Publisher Platform       Genre Release_Year  NA_Sales  \
# 6646                   Screenlife      PSV      Action       2016.0      0.00
# 13689  Disney Interactive Studios       DS      Action       2005.0      0.15
# 10628                 Deep Silver      Wii  Simulation       2008.0      0.26
# 8004                       Capcom      PSP    Platform       2006.0      0.12
# 18                Electronic Arts      N64      Action       2000.0      1.13
# ...                           ...      ...         ...          ...       ...
# 10647                     Compile      N64      Puzzle       1997.0      0.00
# 11288                       Atari       PC  Simulation       2016.0      0.00
# 13754                         THQ      GBA    Platform       2002.0      0.14
# 4501                          THQ      PS2      Action   2003-05-09      1.26
# 13439                      Capcom      Wii    Fighting       2008.0      0.00
#
#        EU_Sales  JP_Sales  Other_Sales
# 6646       0.00      0.03         0.00
# 13689      0.01      0.00         0.01
# 10628      0.00      0.00         0.02
# 8004       0.01      0.00         0.02
# 18         0.38      0.02         0.03
# ...         ...       ...          ...
# 10647      0.00      0.16         0.03
# 11288      0.02      0.00         0.00
# 13754      0.05      0.00         0.00
# 4501       0.60      0.05         0.18
# 13439      0.00      0.10         0.00
#
# [1000 rows x 9 columns]

# %% [markdown]
# Agent Code

# %%
class Agent:
    def __init__(self, dna=None):
        #self.dna = dna if dna is None else
